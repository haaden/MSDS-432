# %% [markdown]
# •	Go to this website and choose one of the Top 20 Dynamic Programming Interview Questions for this assignment.  https://www.geeksforgeeks.org/top-20-dynamic-programming-interview-questions/ (Links to an external site.)
#
# •	Implement the Dynamic Programming algorithm in Python (it's ok to use the code that's on the webpage) and use it to solve a range of scenarios.  Make sure you are using a Dynamic Programming solution (not another one)
#
# •	Explain what is being done in the implementation.  That is, write up a walk through of the algorithm and explain how it is a Dynamic Programming solution.

# %% [markdown]
# # Longest Common Subsequence
#
# Refrence:
#
# https://www.geeksforgeeks.org/longest-common-subsequence-dp-4/
#
# https://www.geeksforgeeks.org/printing-longest-common-subsequence/
#
# https://thecodingbot.com/how-to-colour-a-specific-cell-in-pandas-dataframe-based-on-its-position/

# %% [markdown]
# LCS Problem Statement: Given two sequences, find the length of longest subsequence present in both of them. A subsequence is a sequence that appears in the same relative order, but not necessarily contiguous. For example, “abc”, “abg”, “bdf”, “aeg”, ‘”acefg”, .. etc are subsequences of “abcdefg”.

# %% [markdown]
# The longest common subsequence (LCS) is defined as the longest subsequence that is common to all the given sequences, provided that the elements of the subsequence are not required to occupy consecutive positions within the original sequences.

# %%
import numpy as np
import pandas as pd

from platform import python_version

print("python version",python_version())
# Out:
# python version 3.8.5

# %%
# Dynamic Programming implementation of LCS problem
  
def lcs(X , Y):
    # find the length of the strings
    m = len(X)
    n = len(Y)
  
    # declaring the array for storing the dp values
    L = [[None]*(n+1) for i in range(m+1)]

    
    #print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
    
  
    """Following steps build L[m+1][n+1] in bottom up fashion
    Note: L[i][j] contains length of LCS of X[0..i-1]
    and Y[0..j-1]"""
    for i in range(m+1):
        for j in range(n+1):
            if i == 0 or j == 0 :
                L[i][j] = 0
                #print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
            elif X[i-1] == Y[j-1]:
                L[i][j] = L[i-1][j-1]+1
               
            #print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
            else:
                L[i][j] = max(L[i-1][j] , L[i][j-1])
                #print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
    index = L[m][n]
    #print(index)
  
    # Create a character array to store the lcs string
    lcs = [""] * (index+1)
    lcs[index] = ""
    #print(lcs)
  
    # Start from the right-most-bottom-most corner and
    # one by one store characters in lcs[]
    i = m
    j = n
    while i > 0 and j > 0:
  
        # If current character in X[] and Y are same, then
        # current character is part of LCS
        if X[i-1] == Y[j-1]:
            lcs[index-1] = X[i-1]
            #print(lcs)
            i-=1
            j-=1
            index-=1
  
        # If not same, then find the larger of two and
        # go in the direction of larger value
        elif L[i-1][j] > L[i][j-1]:
            
            i-=1
        else:
            j-=1
  
  
    # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1]
    return   ''.join(lcs),L[m][n]
#end of function lcs
  
  
# Driver program to test the above function
X = "AGGTAB"
Y = "GXTXAYB"
print ("LCS and Length of LCS is ", lcs(X, Y))
  
# This code is contributed by Nikhil Kumar Singh(nickzuck_007)
# Out:
# LCS and Length of LCS is  ('GTAB', 4)

# %% [markdown]
# Dynamic programming is used where we have problems which can be divided into similar sub-problems, so that their results can be re-used. This reduces the number of function calls.
#
# In the above dynamic algorithm, we use the tabulation method (bottom up approach), where the results obtained from each comparison between elements of X and the elements of Y (sub-problem) are stored in a table so that they can be used in future computations. Once the table is filled in, we compute the solution to the original problem based on the results in this table.

# %% [markdown]
# # Step 1

# %% [markdown]
# Lets assume that the two strings to be compared are assigned to variables X and Y.
#
# First we initialize an empty matrix of len(Y + 1) x (len(X+1) to set up the table.

# %%
m = len(X)
n = len(Y)
  
# declaring the array for storing the dp values
L = [[None]*(n+1) for i in range(m+1)]


print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
# Out:
#       0     G     X     T     X     A     Y     B
# 0  None  None  None  None  None  None  None  None
# A  None  None  None  None  None  None  None  None
# G  None  None  None  None  None  None  None  None
# G  None  None  None  None  None  None  None  None
# T  None  None  None  None  None  None  None  None
# A  None  None  None  None  None  None  None  None
# B  None  None  None  None  None  None  None  None

# %% [markdown]
# # Step 2   and 3

# %% [markdown]
# Using a for loop using range function, we  by default set the  first row and column as zero because if we compare null string with any string, the count of matching string will be zero.
#
# If the first character of the vertically aligned string in the dynamic table matches the first character of the horizontally aligned string, then we take a previous diagonal value and add one to it.
#
# If there is no match, then we look at the values in the previous row and column and take the maximum value.

# %% [markdown]
# Repeat this step for every vertically and horizontally aligned strings.

# %%
for i in range(m+1):
        for j in range(n+1):
            if i == 0 or j == 0 :
                L[i][j] = 0
                print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
            elif X[i-1] == Y[j-1]:
                L[i][j] = L[i-1][j-1]+1
                print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
            else:
                L[i][j] = max(L[i-1][j] , L[i][j-1])
                print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
                
df = pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X))
# Out:
#       0     G     X     T     X     A     Y     B
# 0     0  None  None  None  None  None  None  None
# A  None  None  None  None  None  None  None  None
# G  None  None  None  None  None  None  None  None
# G  None  None  None  None  None  None  None  None
# T  None  None  None  None  None  None  None  None
# A  None  None  None  None  None  None  None  None
# B  None  None  None  None  None  None  None  None
#
#       0     G     X     T     X     A     Y     B
# 0     0     0  None  None  None  None  None  None
# A  None  None  None  None  None  None  None  None
# G  None  None  None  None  None  None  None  None
# G  None  None  None  None  None  None  None  None
# T  None  None  None  None  None  None  None  None
# A  None  None  None  None  None  None  None  None
# B  None  None  None  None  None  None  None  None
#
#       0     G     X     T     X     A     Y     B
# 0     0     0     0  None  None  None  None  None
# A  None  None  None  None  None  None  None  None
# ...

# %% [markdown]
# Once the table is filled, the bottom right cell will show the length of LCS.

# %%
df.iloc[m,n]
# Out:
# 4

# %% [markdown]
# # Step 3

# %% [markdown]
# Now that the table is filled we compute the solution.
#
# Create a character array to store the lcs string.
#
# Start from the bottom-right corner [ i ][ j ] and one by one store characters in lcs. We will check if characters at the ith index in string1 and the jth index in string2 are equal. If they are equal, we will append it to our answer variable and then move diagonally upward. If not, we will check which cell has the higher value. Is it the one to the left or the one to the top and accordingly, we will either reduce the value of i or j.
#
# Once the table is traversed. we get our final solution

# %%
index = L[m][n]
lcs = [""] * (index+1)
print(lcs)
lcs[index] = ""

i = m
j = n
while i > 0 and j > 0:

    # If current character in X[] and Y are same, then
    # current character is part of LCS
    if X[i-1] == Y[j-1]:
        #print('x',X[i-1],'y',Y[i-1])
        #print(np.array(L))
        lcs[index-1] = X[i-1]
        print(lcs)
        i-=1
        j-=1
        index-=1

    # If not same, then find the larger of two and
    # go in the direction of larger value
    elif L[i-1][j] > L[i][j-1]:

        i-=1
    else:
        j-=1
# Out:
# ['', '', '', '', '']
# ['', '', '', 'B', '']
# ['', '', 'A', 'B', '']
# ['', 'T', 'A', 'B', '']
# ['G', 'T', 'A', 'B', '']

# %%
def lcs(X , Y):
    # find the length of the strings
    m = len(X)
    n = len(Y)
  
    # declaring the array for storing the dp values
    L = [[None]*(n+1) for i in range(m+1)]

    
    #print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
    
  
    """Following steps build L[m+1][n+1] in bottom up fashion
    Note: L[i][j] contains length of LCS of X[0..i-1]
    and Y[0..j-1]"""
    for i in range(m+1):
        for j in range(n+1):
            if i == 0 or j == 0 :
                L[i][j] = 0
                #print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
            elif X[i-1] == Y[j-1]:
                L[i][j] = L[i-1][j-1]+1
               
            #print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
            else:
                L[i][j] = max(L[i-1][j] , L[i][j-1])
                #print(pd.DataFrame(np.array(L), columns=list('0'+Y), index=list('0'+X)),'\n')
    index = L[m][n]
    #print(index)
  
    # Create a character array to store the lcs string
    lcs = [""] * (index+1)
    lcs[index] = ""
    #print(lcs)
  
    # Start from the right-most-bottom-most corner and
    # one by one store characters in lcs[]
    i = m
    j = n
    while i > 0 and j > 0:
  
        # If current character in X[] and Y are same, then
        # current character is part of LCS
        if X[i-1] == Y[j-1]:
            lcs[index-1] = X[i-1]
            #print(lcs)
            i-=1
            j-=1
            index-=1
  
        # If not same, then find the larger of two and
        # go in the direction of larger value
        elif L[i-1][j] > L[i][j-1]:
            
            i-=1
        else:
            j-=1
  
  
    # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1]
    return   ''.join(lcs),L[m][n]

# %% [markdown]
# # solve a range of scenarios

# %%
# no common strings

X= 'abcd'
Y ='efgh'

# the strings are case sensitive and wont work if comparing upper and lower case strings
A = 'ABQRST'
B = 'abqrst'

# numeric string value

E = '1234'
F = '345656'
print("LCS and Length of LCS is",lcs(X,Y))
print("LCS and Length of LCS is",lcs(A,B))
print ("LCS and Length of LCS is", lcs(E,F))
# Out:
# LCS and Length of LCS is ('', 0)
# LCS and Length of LCS is ('', 0)
# LCS and Length of LCS is ('34', 2)

# %% [markdown]
# # Discussion and Executive summary

# %% [markdown]
# Time Complexity of the above implementation is O(m * n), where m and n are length of two strings. This is because of the two nested loops. This problem could be solved recursively but the time complexity would be O(n^2) as it would involve solving problems repeatedly. This problem has Overlapping Substructure property and re-computation of the same subproblems can be avoided by either using the Memorization or Tabulation method of dynamic programming. The above LCS problem is solved using the tabulation method.
#
# As data engineers, we should have the  knowledge to identify if a problem is well-suited for dynamic programming as this would significantly impact processing time.
